# %% [markdown]
# # GRIPJANUARY Task4: Problem Statement : Perform 'Exploratory Data Analysis' on dataset global terrorism

# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gl=pd.read_csv("C:/Users/LENOVO/Downloads/Global Terrorism - START data (1).zip",encoding='latin1')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_69428\2511055291.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   gl=pd.read_csv("C:/Users/LENOVO/Downloads/Global Terrorism - START data (1).zip",encoding='latin1')

# %%
gl
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
gl.shape
# Out:
# (181691, 135)

# %%
gl.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
gl.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
gl.size
# Out:
# 24528285

# %%
# statistical descripation
gl.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
gl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
gl.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
gl['approxdate'].fillna(gl['approxdate'].mode()[0],inplace=True)
gl['related'].fillna(gl['related'].mode()[0], inplace=True)

# %%
gl.isnull().sum()
# Out:
# eventid       0
# iyear         0
# imonth        0
# iday          0
# approxdate    0
#              ..
# INT_LOG       0
# INT_IDEO      0
# INT_MISC      0
# INT_ANY       0
# related       0
# Length: 135, dtype: int64

# %%
gl.duplicated().sum()
# Out:
# 0

# %%
gl.rename(columns={'iyear':'Year','imonth':'Month','extended':'Extended','iday':'day','country_txt':'Country','provstate':'state',
                  'region_txt':'Region','attacktypl_txt':'AttackType','target1':'target','weaptype1_txt':'Weapon_type','nkill':'killed',
                  'gname':'Group','city':'City','latitude':'Latitude','longitude':'Longitude','nwound':'wounded'},inplace=True)
gl.head()
# Out:
#         eventid  Year  Month  day             approxdate  Extended resolution  \
# 0  197000000001  1970      7    2  September 18-24, 2016         0        NaN
# 1  197000000002  1970      0    0  September 18-24, 2016         0        NaN
# 2  197001000001  1970      1    0  September 18-24, 2016         0        NaN
# 3  197001000002  1970      1    0  September 18-24, 2016         0        NaN
# 4  197001000003  1970      1    0  September 18-24, 2016         0        NaN
#
#    country             Country  region  ... addnotes scite1 scite2  scite3  \
# 0       58  Dominican Republic       2  ...      NaN    NaN    NaN     NaN
# 1      130              Mexico       1  ...      NaN    NaN    NaN     NaN
# 2      160         Philippines       5  ...      NaN    NaN    NaN     NaN
# 3       78              Greece       8  ...      NaN    NaN    NaN     NaN
# 4      101               Japan       4  ...      NaN    NaN    NaN     NaN
#
# ...

# %%
#consider only required columns
df=gl[['Year','Month','Extended','day','Country','state','Region','City','Latitude','Longitude','killed',
     'Group','target' ]]
df.head()
# Out:
#    Year  Month  Extended  day             Country    state  \
# 0  1970      7         0    2  Dominican Republic      NaN
# 1  1970      0         0    0              Mexico  Federal
# 2  1970      1         0    0         Philippines   Tarlac
# 3  1970      1         0    0              Greece   Attica
# 4  1970      1         0    0               Japan  Fukouka
#
#                         Region           City   Latitude   Longitude  killed  \
# 0  Central America & Caribbean  Santo Domingo  18.456792  -69.951164     1.0
# 1                North America    Mexico city  19.371887  -99.086624     0.0
# 2               Southeast Asia        Unknown  15.478598  120.599741     1.0
# 3               Western Europe         Athens  37.997490   23.762728     NaN
# 4                    East Asia        Fukouka  33.580412  130.396361     NaN
#
#                                 Group                   target
# 0                              MANO-D             Julio Guzman
# ...

# %%
# plotting the heatmap
import seaborn as sns 
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Top 10 country Affected

# %%
# gets the individual count of each country 
country_count =df['Country'].value_counts()
# get the top 10 countries by sclicing 
country_count10=country_count[:10]
print(country_count10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %%
# create figure (empty canvas)
fig =plt.figure(figsize =(10,6))
sns.barplot(df['Country'].value_counts()[:10].index,df['Country'].value_counts()[:10].values)
plt.title('top 10 Countries Affected')
plt.xlabel('Countries')
plt.ylabel('Counts')
# rotate the lables on x_axis so that they don't overlap
plt.xticks(rotation=90);
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 2 Terrorist Activities According to the year

# %%
fig=plt.figure(figsize=(15,6))
sns.countplot('Year',data=df,order=df['Year'].value_counts().index,palette='rainbow')
plt.xticks(rotation=90)
plt.xticks(rotation=90)
plt.title('Trrorist Activities According to the Year')
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Trrorist Activities According to the Year')

# %%
print("most Affected states are :\n",df['state'].value_counts().head())
# Out:
# most Affected states are :
#  Baghdad             7645
# Northern Ireland    4498
# Unknown             4290
# Balochistan         3710
# Saladin             3411
# Name: state, dtype: int64

# %%
# create figure (empty canves)
fig=plt.figure(figsize=(15,6))
sns.barplot(df['state'].value_counts()[:10].index,df['state'].value_counts()[:10].values,palette='rocket')
plt.title('top 10 states Affected')
plt.xlabel('states')
plt.ylabel('Counts')                                      
 # rotate the on x-axis  so that they dont overlap
plt.xticks (rotation=90);
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Group With most terrorist attacks
fig=plt.figure(figsize=(15,6))
sns.barplot(df['Group'].value_counts()[:10].index,df['Group'].value_counts()[:10].values,palette='rocket')
plt.title('Group with Most Terrorist Attacks')
plt.xlabel('Group')
plt.ylabel('Counts')
# Rotate the on X-axis so that they don't overlap
plt.xticks(rotation=90);
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Exploratory Data Analysis(EDA) are:
# 1 most Affected Country Iraq
# 2  the year 2014 has observed that the most number of  terrorist Activities
# 3 Baghdad is the most affected state  due to terrorism
# 4 An Unknown group is the most active Terrorist organisation followed by the Taliban
# 5 middle East and North Africa is the most affected region due to Terrorism
